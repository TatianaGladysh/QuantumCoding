# %%
from qiskit import QuantumCircuit
import qiskit.quantum_info as qi
from qiskit.quantum_info import Statevector

# %%
#prerare entangled state
qc_AB = QuantumCircuit(2)
qc_AB.h(0)
qc_AB.cx(0,1)
qc_AB.draw(output="mpl")

# %%
psi_AB = qi.Statevector.from_instruction(qc_AB)
psi_AB = qi.Statevector(qc_AB)
psi_AB.draw(output='latex')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
#psi_AB.draw('latex', prefix='|\\psi_{AB}\\rangle = ')
sv=Statevector([1/sqrt(2), 0, 0, -1/sqrt(2)])
sv.draw(output='latex')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle- \frac{\sqrt{2}}{2} |11\rangle$$

# %%
rho_AB = qi.DensityMatrix.from_instruction(qc_AB)
rho_AB.draw('latex', prefix='\\rho_{AB} = ')
# Out:
# $$
# \rho_{AB} =
# \begin{bmatrix}
# \tfrac{1}{2} & 0 & 0 & \tfrac{1}{2}  \\
#  0 & 0 & 0 & 0  \\
#  0 & 0 & 0 & 0  \\
#  \tfrac{1}{2} & 0 & 0 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
#let's make our density matrix
sv1=Statevector([1/sqrt(2), 0, 0, -1/sqrt(2)])
sv1=Statevector([0, -1/sqrt(2), 0, -1/sqrt(2)])
sv1.draw(output='latex')
# Out:
# $$- \frac{\sqrt{2}}{2} |01\rangle- \frac{\sqrt{2}}{2} |11\rangle$$

# %%
sv2.draw(output='latex')
# Out:
# $$- \frac{\sqrt{2} i}{2} |01\rangle- \frac{\sqrt{2}}{2} |11\rangle$$

# %%
rho_1 = qi.DensityMatrix(sv1)
rho_1.draw('latex', prefix='\\rho_{1} = ')
# Out:
# $$
# \rho_{1} =
# \begin{bmatrix}
# 0 & 0 & 0 & 0  \\
#  0 & \tfrac{1}{2} & 0 & \tfrac{1}{2}  \\
#  0 & 0 & 0 & 0  \\
#  0 & \tfrac{1}{2} & 0 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
rho_2 = qi.DensityMatrix(sv2)
rho_2.draw('latex', prefix='\\rho_{2} = ')
# Out:
# $$
# \rho_{2} =
# \begin{bmatrix}
# 0 & 0 & 0 & 0  \\
#  0 & \tfrac{1}{2} & 0 & \tfrac{1}{2}i  \\
#  0 & 0 & 0 & 0  \\
#  0 & -\tfrac{1}{2}i & 0 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.visualization import plot_state_city
plot_state_city(rho_2.data, title='Density Matrix')

# %%
# rho_0 = 1/3*qi.DensityMatrix.from_label('1') + 2/3*qi.DensityMatrix.from_label('+')
# rho_0.draw('latex', prefix='\\rho_0 = ')
rho_sum= 1/3*rho_1+2/3*rho_2
rho_sum.draw('latex', prefix='\\rho_{sum} = ')
# Out:
# $$
# \rho_{sum} =
# \begin{bmatrix}
# 0 & 0 & 0 & 0  \\
#  0 & \tfrac{1}{2} & 0 & \tfrac{1}{6} + \tfrac{1}{3}i  \\
#  0 & 0 & 0 & 0  \\
#  0 & \tfrac{1}{6} - \tfrac{1}{3}i & 0 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.opflow import I, X, Y, Z
rho_1.expectation_value(X^X)
# Out:
# 0j

# %%
import numpy as np
rho_H_matrix = np.array([[1/2,np.sqrt(3)/20 + 2/5],[np.sqrt(3)/20 + 2/5,1/2]])
rho_H = qi.DensityMatrix(rho_H_matrix)
rho_H.draw('latex', prefix='\\rho_H = ')
# Out:
# $$
# \rho_H =
# \begin{bmatrix}
# \tfrac{1}{2} & 0.4866  \\
#  0.4866 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(rho_H.data)

# %%
plot_bloch_multivector(rho_2.data)
